# %%
# Kết nối Google Drive
from google.colab import drive
drive.mount("/content/gdrive")

# %%
# Chỉ định thư mục làm việc hiện hành
import os
colab_dir = '/content/gdrive/My Drive/kth'
# my_dir    = '/final'
path      = colab_dir 

# Chuyển thư mục hiện hành
# %cd $path
# Out:
# /content/gdrive/My Drive/kth

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import ticker as mtick
import seaborn as sns

# %%
# Data Visualization
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#--------------------------------------------------------------------
# Kết thúc session hiện hành: 
#    Top-right corner menu: Manage sessions > Terminate
#-------------------------------------------------------------------- 
# Install xlrd phiên bản 1.2.0 trở về sau để có  thể mở tập tin Excel
# !pip install xlrd==2.0.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 KB 3.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 1.2.0
#     Uninstalling xlrd-1.2.0:
#       Successfully uninstalled xlrd-1.2.0
# ...

# %%
# Thư viện
import numpy  as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import plotly.graph_objects as go
# Dữ liệu

# %%
orders = pd.read_excel('/content/[YoRE][KINH TẾ HỌC - TẦM NHÌN BẠN VÀ TÔI 2023][SUPERSTORE].xls',sheet_name='Orders')
returns = pd.read_excel('/content/[YoRE][KINH TẾ HỌC - TẦM NHÌN BẠN VÀ TÔI 2023][SUPERSTORE].xls',sheet_name='Returns')
# people = pd.read_excel('/content/[YoRE][KINH TẾ HỌC - TẦM NHÌN BẠN VÀ TÔI 2023][SUPERSTORE].xls',sheet_name='People')

# %%
df = pd.merge(orders,returns, right_on='Order ID',left_on='Order_ID',how ='left')

# %%
df.drop('Order ID', axis=1, inplace=True)

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
drop=pd.read_csv('true_data.csv')

# %%
drop
# Out:
#       Unnamed: 0  Row_ID        Order_ID  Order_Date   Ship_Date  \
# 0              0       1  CA-2016-152156  2016-11-08  2016-11-11
# 1              1       2  CA-2016-152156  2016-11-08  2016-11-11
# 2              2       3  CA-2016-138688  2016-06-12  2016-06-16
# 3              3       4  US-2015-108966  2015-10-11  2015-10-18
# 4              4       5  US-2015-108966  2015-10-11  2015-10-18
# ...          ...     ...             ...         ...         ...
# 9189        9986    9987  CA-2016-125794  2016-09-29  2016-10-03
# 9190        9987    9988  CA-2017-163629  2017-11-17  2017-11-21
# 9191        9988    9989  CA-2017-163629  2017-11-17  2017-11-21
# 9192        9989    9990  CA-2014-110422  2014-01-21  2014-01-23
# 9193        9993    9994  CA-2017-119914  2017-05-04  2017-05-09
#
#            Ship_Mode Customer_ID     Customer_Name    Segment        Country  \
# 0       Second Class    CG-12520       Claire Gute   Consumer  United States
# ...

# %%
df['Order_Date']=pd.to_datetime(df['Order_Date'], format='%m/%d/%Y')
df['Ship_Date']=pd.to_datetime(df['Ship_Date'], format='%m/%d/%Y')

# %%
df['OrderY']=df['Order_Date'].dt.year
df['OrderM']=df['Order_Date'].dt.month
df['OrderD']=df['Order_Date'].dt.day

# %%
returned= df.loc[df['Returned'] =="Yes"]
no_return= df.loc[df['Returned'] !="Yes"]

# %%
returned
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 18        19  CA-2014-143336 2014-08-27 2014-09-01    Second Class
# 19        20  CA-2014-143336 2014-08-27 2014-09-01    Second Class
# 20        21  CA-2014-143336 2014-08-27 2014-09-01    Second Class
# 55        56  CA-2016-111682 2016-06-17 2016-06-18     First Class
# 56        57  CA-2016-111682 2016-06-17 2016-06-18     First Class
# ...      ...             ...        ...        ...             ...
# 9957    9958  US-2014-143287 2014-11-11 2014-11-17  Standard Class
# 9958    9959  US-2014-143287 2014-11-11 2014-11-17  Standard Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
#
#      Customer_ID       Customer_Name      Segment        Country  \
# 18      ZD-21925  Zuschuss Donatelli     Consumer  United States
# ...

# %%
no_return.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9194 entries, 0 to 9993
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         9194 non-null   int64
#  1   Order_ID       9194 non-null   object
#  2   Order_Date     9194 non-null   datetime64[ns]
#  3   Ship_Date      9194 non-null   datetime64[ns]
#  4   Ship_Mode      9194 non-null   object
#  5   Customer_ID    9194 non-null   object
#  6   Customer_Name  9194 non-null   object
#  7   Segment        9194 non-null   object
#  8   Country        9194 non-null   object
#  9   City           9194 non-null   object
#  10  State          9194 non-null   object
#  11  Postal_Code    9194 non-null   int64
#  12  Region         9194 non-null   object
#  13  Product_ID     9194 non-null   object
#  14  Category       9194 non-null   object
#  15  Sub_Category   9194 non-null   object
#  16  Product_Name   9194 non-null   object
# ...

# %%
Order_date = no_return.groupby(['OrderY','OrderM']).agg({'Discount': 'mean'}).round(3)

# %%
# Convert Order_Date column to datetime
no_return['Order_Date'] = pd.to_datetime(no_return['Order_Date'])

# Group by Order_Date and sum Sales and Profit
monthly_data = no_return.groupby(['Order_Date'], as_index=False).sum()[['Order_Date' , 'Sales' , 'Profit']]

# Set the Order Date column as the index of the dataframe
monthly_data = monthly_data.set_index('Order_Date')

# Resample the data into monthly intervals
monthly_data = monthly_data.resample('M').sum() 

monthly_data.reset_index(inplace=True)

# Transforming Column For Clarification
monthly_data["Month"] = [str(k.month)+'/'+str(k.year) for k in monthly_data['Order_Date'] ]
monthly_data.rename(columns = {"Month":'Order Date'}, inplace = True)
monthly_data = monthly_data.set_index('Order Date')

print(monthly_data)
# Out:
#            Order_Date        Sales      Profit
# Order Date
# 1/2014     2014-01-31   14198.2350   2435.1079
# 2/2014     2014-02-28    4508.5280    866.8309
# 3/2014     2014-03-31   54389.1790    385.4276
# 4/2014     2014-04-30   28061.3550   3412.3255
# 5/2014     2014-05-31   21974.3670   2730.7152
# 6/2014     2014-06-30   33631.4076   4851.8348
# 7/2014     2014-07-31   29684.6290   2783.4498
# 8/2014     2014-08-31   22796.5605   4213.8494
# 9/2014     2014-09-30   73593.7488   5728.3608
# 10/2014    2014-10-31   29124.4310   4304.2121
# 11/2014    2014-11-30   76389.2927   8712.2701
# 12/2014    2014-12-31   66676.2165   8648.9129
# 1/2015     2015-01-31   16131.6376  -2116.7312
# 2/2015     2015-02-28   10644.6710   2630.4063
# 3/2015     2015-03-31   37756.6400   9502.4764
# 4/2015     2015-04-30   30478.8465   3238.9964
# 5/2015     2015-05-31   25882.6185   3370.0387
# 6/2015     2015-06-30   24169.6280   3286.9326
# 7/2015     2015-07-31   28594.9730   3305.6835
# ...

# %%
import matplotlib.pyplot as plt

# Plot
plt.figure(figsize=(25,8))
plt.plot(monthly_data['Sales'],label='Sales')
# plt.axvline(monthly_data.sort_values(by = ["Sales"] , ascending = False).reset_index()['Order Date'][0], color='black')

plt.xlabel("Order Date")
plt.ylabel("Sales")
plt.title("MONTHLY SALES")
plt.xticks(rotation='vertical')

# Plotting the second line chart on the same plot
plt.plot(monthly_data['Profit'], label='Profit')
plt.ylabel('Sales| Profit')
plt.legend()
plt.grid(axis = 'y')
plt.show()

# %%
df_sorted = Order_date.sort_values('Discount', icending=False)

# %%
Order_date = pd.DataFrame(Order_date)

# %%
# Convert Order_Date column to datetime
no_return['Order_Date'] = pd.to_datetime(no_return['Order_Date'])

# Group by Order_Date and sum Sales and Profit
discount_data = no_return.groupby(['Order_Date'], as_index=False).mean()[['Order_Date' , 'Discount']]

# Set the Order Date column as the index of the dataframe
discount_data = discount_data.set_index('Order_Date')

# Resample the data into monthly intervals
discount_data = discount_data.resample('M').sum() 

discount_data.reset_index(inplace=True)

# Transforming Column For Clarification
discount_data["Month"] = [str(k.month)+'/'+str(k.year) for k in discount_data['Order_Date'] ]
discount_data.rename(columns = {"Month":'Order Date'}, inplace = True)
discount_data = discount_data.set_index('Order Date')

print(discount_data)
# Out:
#            Order_Date  Discount
# Order Date
# 1/2014     2014-01-31  3.990455
# 2/2014     2014-02-28  3.883333
# 3/2014     2014-03-31  4.043377
# 4/2014     2014-04-30  2.706364
# 5/2014     2014-05-31  3.981310
# 6/2014     2014-06-30  4.325797
# 7/2014     2014-07-31  2.788611
# 8/2014     2014-08-31  2.841094
# 9/2014     2014-09-30  4.728352
# 10/2014    2014-10-31  4.366051
# 11/2014    2014-11-30  4.028279
# 12/2014    2014-12-31  4.945163
# 1/2015     2015-01-31  2.685000
# 2/2015     2015-02-28  1.772857
# 3/2015     2015-03-31  3.507205
# 4/2015     2015-04-30  4.576687
# 5/2015     2015-05-31  5.009949
# 6/2015     2015-06-30  3.678175
# 7/2015     2015-07-31  4.295708
# 8/2015     2015-08-31  3.335474
# 9/2015     2015-09-30  3.307157
# 10/2015    2015-10-31  4.103323
# 11/2015    2015-11-30  4.235381
# 12/2015    2015-12-31  3.547397
# 1/2016     2016-01-31  2.373106
# 2/2016     2016-02-29  2.366263
# 3/2016     2016-03-31  4.383564
# 4/2016     2016-04-30  4.193695
# ...

# %%
discount_date.plot(figsize=(15, 6))

plt.ylabel('Discount')
# setting the chart title
plt.title('Discount Time Series Data')
plt.show()

# %%
Order_date.dtypes
# Out:
# Discount    float64
# Profit      float64
# Sales       float64
# year          int64
# dtype: object

# %%
Order_date['year'] = Order_date.index.get_level_values(0)

# %%
monthly = no_return.groupby('Order_Date').agg({'Discount': 'mean',
                                   'Profit' : 'sum',
                                   'Sales' : 'sum'}).round(3)

# %%
import seaborn as sbn

# %%
import matplotlib.dates as mdates
yearsFmt = mdates.DateFormatter('%Y')


fig, ax1 = plt.subplots()

color = 'r'
ax1.set_xlabel('Year-Month')
ax1.set_ylabel('Sales (USD)', color = color)
ax1.plot(monthly['datetime'], monthly['Sales'], color=color,linewidth = 2)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis


color = 'tab:blue'
ax2.set_ylabel('Profit (USD)', color=color)  # we already handled the x-label with ax1
ax2.plot(monthly['datetime'],monthly['Profit'], color=color,linewidth = 2)
ax2.tick_params(axis='y', labelcolor=color)
#ax2.yaxis.lim([-5000,25000])
ax2.xaxis.set_major_formatter(
    mdates.ConciseDateFormatter(ax2.xaxis.get_major_locator()))
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Monthly Revenue and Profit')
plt.show()

# %%
sale_no_return=no_return.groupby(['OrderY','OrderM'])['Sales'].sum()
profit_no_return=no_return.groupby(['OrderY','OrderM'])['Profit'].sum()
discount=no_return.groupby(['OrderY','OrderM'])['Discount'].sum()

# %%
sale_no_return
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1844118d1645> in <cell line: 1>()
# ----> 1 sale_no_return
#
# NameError: name 'sale_no_return' is not defined

# %%
import matplotlib.pyplot as plt

# Plotting the first line chart
sale_no_return.plot(figsize=(15, 6), label='Sales')
plt.ylabel('Avg Daily Sales')
plt.title('Sales and Profit Time Series Data')
plt.legend()

# Plotting the second line chart on the same plot
profit_no_return.plot(figsize=(15, 6), label='Profit')
plt.ylabel('Sales| Profit')
plt.legend()
plt.grid(axis = 'y')
# Displaying the plot
plt.show()

# %% [markdown]
# The general trend of the company is profit, but there are some periods in which profits decrease and then rise again. I think it's because of the discounts
#
# Year to year is showing steady growth in profit. 2015 may be a year to investigate further or at least understand the reason for the lack of growth in revenue, perhaps the business underwent organizational changes to become more profitable.

# %%
import matplotlib.dates as mdates
yearsFmt = mdates.DateFormatter('%Y')

# %%
# creating a custom palette
colors = ['#1192AA','#00B8C0', '#73D4D3', '#FF69B4']

sns.palplot(colors)
plt.gcf().set_size_inches(8,2.5)

for idx,values in enumerate(colors):
    plt.text(idx-0.375,0, colors[idx],{'font': "Courier New", 'size':16, 'weight':'bold','color':'black'}, alpha =0.7)
plt.gcf().set_facecolor('white')

plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# ...

# %%
# create table
data_shipping_time = no_return.copy()
data_shipping_time['Shipping Time'] = pd.to_datetime(data_shipping_time['Ship_Date']) - pd.to_datetime(data_shipping_time['Order_Date'])

data_shipping_time['Shipping Time'] = data_shipping_time['Shipping Time'].dt.days

data_shipping_time = data_shipping_time.groupby('Shipping Time', as_index = False).sum()

sales_data_shipping_time = data_shipping_time.sort_values(by = 'Sales')

# %%
# create table
data_shipping_time = no_return.copy()
data_shipping_time['Shipping Time'] = pd.to_datetime(data_shipping_time['Ship_Date']) - pd.to_datetime(data_shipping_time['Order_Date'])

data_shipping_time['Shipping Time'] = data_shipping_time['Shipping Time'].dt.days

data_shipping_time = data_shipping_time.groupby('Shipping Time', as_index = False).sum()

sales_data_shipping_time = data_shipping_time.sort_values(by = 'Sales')

# plot
fig = px.bar(x = sales_data_shipping_time['Sales'],
             y = sales_data_shipping_time['Shipping Time'],
             orientation = 'h',
             template = 'simple_white',
             color_discrete_sequence = colors)

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="Total Sales",
    yaxis_title="Number of Days",
    showlegend = True,
    font = dict(
            size = 14
            ),    
    title={
        'text': "Total Sales by Average Delivery Time<br>(days)",
        'y':0.95,
        'x':0.5
        }
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data_shipping_time
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer_ID     Customer_Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
# create table
data_shipping_time = no_return.copy()
data_shipping_time['Shipping Time'] = pd.to_datetime(data_shipping_time['Ship_Date']) - pd.to_datetime(data_shipping_time['Order_Date'])

data_shipping_time['Shipping Time'] = data_shipping_time['Shipping Time'].dt.days

data_shipping_time = data_shipping_time.groupby('Shipping Time', as_index = False).sum()

profit_data_shipping_time = data_shipping_time.sort_values(by = 'Profit')

# plot
fig = px.bar(x = profit_data_shipping_time['Profit'],
             y = profit_data_shipping_time['Shipping Time'],
             orientation = 'h',
             template = 'simple_white',
             color_discrete_sequence = colors)

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="Total Profit",
    yaxis_title="Number of Days",
    showlegend = True,
    font = dict(
            size = 14
            ),    
    title={
        'text': "Total Profit by Average Delivery Time<br>(days)",
        'y':0.95,
        'x':0.5
        }
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ship_mode_and_time
# Out:
#         Ship_Mode  Shipping Time
# 0     First Class              2
# 1        Same Day              0
# 2    Second Class              3
# 3  Standard Class              5

# %%
no_return['Order_Date'] = no_return['Order_Date'].astype(str)
no_return['Order_Date'].str.len().value_counts()
# Out:
# 10    9194
# Name: Order_Date, dtype: int64

# %%
no_return[['YearOfOrder', 'MonthOfOrder', 'DayOfOrder']] = no_return['Order_Date'].str.split('-', n=2, expand=True).fillna(-1)

# %% [markdown]
# Looks like most of the orders are placed at the beginning and the middle of the month rather than at the end.
# The last couple of days of the month (the 30th and 31st) had fewer orders than days at the beginning and the middle of the month

# %%
sorted_order_day = no_return.groupby('DayOfOrder')['DayOfOrder'].count().sort_values(ascending=False)
plt.figure(figsize=(15,6))
ax = sorted_order_day.plot.bar()

# %% [markdown]
# Seems like most orders were placed towards the end of the year rather than at the beginning

# %%
sorted_order_month = no_return.groupby('MonthOfOrder')['MonthOfOrder'].count().sort_values(ascending=False)
plt.figure(figsize=(16,5))
ax = sorted_order_month.plot.bar()

# %% [markdown]
# this graph shows arbitrary relation between sales and profit it means that increasing in sales profit is either increased or decreased
#
# result: sales leads to profit as well as loss
#
# Conclusions
# these are 8 recommendations or suggestions to generate more profit
# 1.Discount
# we have to limit our discount from 0 % to 10%
# 2.Category
# We have to increase in sales of that things which comes under technology Category
# 3.sub-Category
# We have to increase in sales of that things which comes under Copiers Category
# 4.Segment
# We have to choose home office segment to generates more profit
# 5.Quantity
# Quantity of items should be in between 1 to 11
# 6.sales
# We have to increase our sale to take more profit but must following other instructions in mind otherwise loss is also happen
# 7.Cities and states
# there are 116 cities and 10 states which generates loss so we have to reduce our sales operations in these cities and states
# 8.region
# central region generates very less profit so we have to reduce our sales operations in central region

# %% [markdown]
# the best salles
# The best sales are when the discount is 50%, but this leads to loss and non-profitability.
#
# The discount from 10 to 20%. Is the best solution, as they are the second and third best sellers and make profits

# %%
no_return
# Out:
#       Row_ID        Order_ID  Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2016-152156  2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156  2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688  2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966  2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966  2015-10-11 2015-10-18  Standard Class
# ...      ...             ...         ...        ...             ...
# 9986    9987  CA-2016-125794  2016-09-29 2016-10-03  Standard Class
# 9987    9988  CA-2017-163629  2017-11-17 2017-11-21  Standard Class
# 9988    9989  CA-2017-163629  2017-11-17 2017-11-21  Standard Class
# 9989    9990  CA-2014-110422  2014-01-21 2014-01-23    Second Class
# 9993    9994  CA-2017-119914  2017-05-04 2017-05-09    Second Class
#
#      Customer_ID     Customer_Name    Segment        Country             City  \
# ...

# %% [markdown]
# Primary Data Visualization
# The primary objective is to gain insight into our transactions and how this knowledge can guide our business. Understanding the customer base and where the most opportunity lies is the key to successfully grow.
#
# To start we will visualize our sales and profit and how they have evolved through the transaction history,both in a yearly and monthly view.

# %%
# create timeseries table, group by order date and sum sales and profit
data_timeseries = df.copy()
data_timeseries = data_timeseries[['Order_Date', 'Sales', 'Profit']].groupby('Order_Date', as_index = False).sum()

# convert order date column to timestemp datatype
data_timeseries['Order_Date'] = pd.to_datetime(data_timeseries['Order_Date'])

# sort by date
data_timeseries = data_timeseries.sort_values(by = 'Order_Date')

# Plot

fig = px.area(x = data_timeseries['Order_Date'],
              y = data_timeseries['Sales'],
              template = 'simple_white',
              color_discrete_sequence = colors,
             )
plt.show()

# %% [markdown]
# Sales & Profit

# %%
plt.figure(figsize = (10,7))
sns.countplot(x = df['Category'], hue = df['Ship_Mode'])
plt.show()

# %% [markdown]
# Observation - Standard class always the preferred ship by the customer and the less prefered ship mode is same day.

# %% [markdown]
# Analyzing Sales and Profit
# 1. By Ship Mode

# %%
def avg_bar(column):
    profit = df['Profit'].groupby(df[column]).mean()
    plt.figure(figsize=(25,10))
    sns.barplot(data=profit, x=profit.index, y=profit.values, palette='dark')
    # plt.grid()
    plt.title('Average Profit - per {}'.format(column), fontsize=18)
    plt.ylabel('Profit', fontsize=16)
    plt.xlabel('{}'.format(column), fontsize=16)
    plt.show()

# %%
import matplotlib
matplotlib.axes.Axes.pie
matplotlib.pyplot.pie
# Out:
# <function matplotlib.pyplot.pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=0, radius=1, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, *, normalize=True, hatch=None, data=None)>

# %%
def pie_percentage(column):
    df1 = df.groupby([column])['Sales', 'Profit', 'Discount'].mean()
    df1.plot.pie(subplots=True, labels = df1.index, autopct='%1.2f%%',figsize = (20,20))

# %%
pie_percentage('Ship_Mode')

# %%
df_ship = df.groupby(['Ship_Mode'])['Sales', 'Profit', 'Discount'].mean()
df_ship
# Out:
#                      Sales     Profit  Discount
# Ship_Mode
# First Class     228.497024  31.839948  0.164610
# Same Day        236.396179  29.266591  0.152394
# Second Class    236.089239  29.535545  0.138895
# Standard Class  227.583067  27.494770  0.160023

# %%
data_shipping_time=no_return.copy()

# %%
data_shipping_time['Shipping Time'] = pd.to_datetime(data_shipping_time['Ship_Date']) - pd.to_datetime(data_shipping_time['Order_Date'])

data_shipping_time['Shipping Time'] = data_shipping_time['Shipping Time'].dt.days

# %%
data_shipping_time['Profit Margin']=round(data_shipping_time['Profit']/data_shipping_time['Sales'],4)*100

# %%
data_shipping_time
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9986    9987  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9987    9988  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988    9989  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer_ID     Customer_Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# ship đối với các đơn thành công

# %%
grouped_state = data_shipping_time.groupby('Shipping Time').agg({'Discount': 'mean',
                                   'Profit' : 'sum',
                                   'Sales' : 'sum',
                                   'Order_ID' : 'count'}).round(3)

# %%
grouped_state['Shipping Time'] = grouped_state.index.get_level_values(0)

# %%
grouped_state
# Out:
#                Discount     Profit       Sales  Order_ID Shipping Time
# Shipping Time
# 0 days            0.152  15385.968  124907.691       519        0 days
# 1 days            0.163   7541.227   67975.331       369        1 days
# 2 days            0.147  53118.114  368465.830      1334        2 days
# 3 days            0.152  26875.919  204659.599      1005        3 days
# 4 days            0.167  71134.774  631847.005      2774        4 days
# 5 days            0.156  58733.204  494357.084      2169        5 days
# 6 days            0.142  33275.968  240290.570      1203        6 days
# 7 days            0.161  20331.847  164697.750       621        7 days

# %%
df_ship = data_shipping_time.groupby(['Ship_Mode'])['Sales', 'Profit', 'Discount','Profit Margin'].mean()
df_ship
# Out:
#                      Sales     Profit  Discount  Profit Margin
# Ship_Mode
# First Class     225.204697  29.532161  0.165887      11.421775
# Same Day        232.802672  26.970630  0.159916      12.264760
# Second Class    236.426716  29.053120  0.142408      14.262165
# Standard Class  229.228273  28.397781  0.159828      11.041147

# %%
df_ship1 = data_shipping_time.groupby(['Shipping Time'])['Sales', 'Profit'].sum()
df_ship1['Profit Margin']= df_ship1['Profit']/df_ship1['Sales'] *100
df_ship1
# Out:
#                      Sales      Profit  Profit Margin
# Shipping Time
# 0              108057.0460  12413.1412      11.487581
# 1               63987.1712   7847.5505      12.264256
# 2              327622.6730  43187.1023      13.181964
# 3              186488.7348  25131.5581      13.476180
# 4              597834.2319  71427.8541      11.947769
# 5              467092.8742  53894.9396      11.538378
# 6              216518.0718  29643.2517      13.690890
# 7              149095.7795  19619.2627      13.158832

# %%
df_ship1['Shipping Time'] = df_ship1.index.get_level_values(0)

# %%
# plot
fig = px.bar(x = df_ship1['Sales'],
             y = df_ship1['Shipping Time'],
             orientation = 'h',
             template = 'simple_white',
             color_discrete_sequence = colors)

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="Total discount",
    yaxis_title="Number of Days",
    showlegend = True,
    font = dict(
            size = 14
            ),    
    title={
        'text': "Total sales by Average Delivery Time<br>(days)",
        'y':0.95,
        'x':0.5
        }
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_ship1 = data_shipping_time.groupby(['Shipping Time'])['Sales', 'Profit'].sum()
df_ship1['Profit Margin']= df_ship1['Profit']/df_ship1['Sales'] *100
df_ship1

# %%
# plot
fig = px.bar(x = df_ship1['Profit'],
             y = df_ship1['Shipping Time'],
             orientation = 'h',
             template = 'simple_white',
             color_discrete_sequence = colors)

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="Total discount",
    yaxis_title="Number of Days",
    showlegend = True,
    font = dict(
            size = 14
            ),    
    title={
        'text': "Total profit by Average Delivery Time<br>(days)",
        'y':0.95,
        'x':0.5
        }
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# plot
fig = px.bar(x = df_ship1['Profit Margin'],
             y = df_ship1['Shipping Time'],
             orientation = 'h',
             template = 'simple_white',
             color_discrete_sequence = colors)

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="Total discount",
    yaxis_title="Number of Days",
    showlegend = True,
    font = dict(
            size = 14
            ),    
    title={
        'text': "Profit Margin by Average Delivery Time<br>(days)",
        'y':0.95,
        'x':0.5
        }
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# plot
fig = px.bar(x = df_ship1['Sales'],
             y = df_ship1['Shipping Time'],
             orientation = 'h',
             template = 'simple_white',
             color_discrete_sequence = colors)

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="Total discount",
    yaxis_title="Number of Days",
    showlegend = True,
    font = dict(
            size = 14
            ),    
    title={
        'text': "Total Profit by Average Delivery Time<br>(days)",
        'y':0.95,
        'x':0.5
        }
    )

fig.show()

# %%
returned_shipping_time=returned.copy()
returned_shipping_time['Shipping Time'] = pd.to_datetime(returned_shipping_time['Ship_Date']) - pd.to_datetime(returned_shipping_time['Order_Date'])

returned_shipping_time['Shipping Time'] = returned_shipping_time['Shipping Time'].dt.days

# %%
returned_shipping_time
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 18        19  CA-2014-143336 2014-08-27 2014-09-01    Second Class
# 19        20  CA-2014-143336 2014-08-27 2014-09-01    Second Class
# 20        21  CA-2014-143336 2014-08-27 2014-09-01    Second Class
# 55        56  CA-2016-111682 2016-06-17 2016-06-18     First Class
# 56        57  CA-2016-111682 2016-06-17 2016-06-18     First Class
# ...      ...             ...        ...        ...             ...
# 9957    9958  US-2014-143287 2014-11-11 2014-11-17  Standard Class
# 9958    9959  US-2014-143287 2014-11-11 2014-11-17  Standard Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
#
#      Customer_ID       Customer_Name      Segment        Country  \
# 18      ZD-21925  Zuschuss Donatelli     Consumer  United States
# ...

# %% [markdown]
# đối với các đơn hoàn lại

# %%
returned_ship = returned_shipping_time.groupby(['Ship_Mode'])['Sales', 'Profit', 'Discount'].mean()
returned_ship
# Out:
#                      Sales     Profit  Discount
# Ship_Mode
# First Class     258.517849  52.883318  0.152961
# Same Day        263.291328  46.450427  0.096094
# Second Class    231.528254  36.055492  0.091418
# Standard Class  207.409186  16.421853  0.162422

# %%
returned_ship1 = returned_shipping_time.groupby(['Shipping Time'])['Sales', 'Profit', 'Discount'].sum()
returned_ship1['Profit Margin']= returned_ship1['Profit']/returned_ship1['Sales'] *100

returned_ship1
# Out:
#                     Sales     Profit  Discount  Profit Margin
# Shipping Time
# 0              16850.6450  2972.8273      6.15      17.642217
# 1               3988.1600  -306.3236      4.60      -7.680825
# 2              40843.1570  9931.0120     10.95      24.314996
# 3              18170.8640  1744.3606     15.60       9.599767
# 4              34012.7734  -293.0799     39.39      -0.861676
# 5              27264.2095  4838.2649     14.65      17.745847
# 6              23772.4980  3632.7160     11.60      15.281171
# 7              15601.9710   712.5842     11.80       4.567270

# %%
returned_ship1['Shipping Time'] = returned_ship1.index.get_level_values(0)

# %%
returned_ship1.columns
# Out:
# Index(['Sales', 'Profit', 'Discount', 'Profit Margin', 'Shipping Time'], dtype='object')

# %%
# plot
fig = px.bar(x = returned_ship1['Discount'],
             y = returned_ship1['Shipping Time'],
             orientation = 'h',
             template = 'simple_white',
             color_discrete_sequence = colors)

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="Total discount",
    yaxis_title="Number of Days",
    showlegend = True,
    font = dict(
            size = 14
            ),    
    title={
        'text': "Total Profit by Average Delivery Time<br>(days)",
        'y':0.95,
        'x':0.5
        }
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
trace3 = go.Scatter(x=df_order_week.index,y= df_order_week['Quantity'], name="Quantity")

# %%
# resample sales data for weekly frequency
df_order_week = df_order_id.resample('W', on='Order Date')['Sales','Profit',,'Quantity'].sum()

# %%
# plot
fig = px.bar(x = returned_ship1['Profit'],
             y = returned_ship1['Shipping Time'],
             orientation = 'h',
             template = 'simple_white',
             color_discrete_sequence = colors)

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="Total Profit",
    yaxis_title="Number of Days",
    showlegend = True,
    font = dict(
            size = 14
            ),    
    title={
        'text': "Total Profit by Average Delivery Time<br>(days)",
        'y':0.95,
        'x':0.5
        }
    )

fig.show()

# %%
# plot
fig = px.bar(x = returned_ship1['Profit'],
             y = returned_ship1['Shipping Time'],
             orientation = 'h',
             template = 'simple_white',
             color_discrete_sequence = colors)

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="Total Profit",
    yaxis_title="Number of Days",
    showlegend = True,
    font = dict(
            size = 14
            ),    
    title={
        'text': "Total Profit by Average Delivery Time<br>(days)",
        'y':0.95,
        'x':0.5
        }
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# plot
fig = px.bar(x = returned_ship1['Sales'],
             y = returned_ship1['Shipping Time'],
             orientation = 'h',
             template = 'simple_white',
             color_discrete_sequence = colors)

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="Total Sales",
    yaxis_title="Number of Days",
    showlegend = True,
    font = dict(
            size = 14
            ),    
    title={
        'text': "Total Sales by Average Delivery Time<br>(days)",
        'y':0.95,
        'x':0.5
        }
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
returned_shipping_time['return_order'] = returned_shipping_time[returned_shipping_time['Returned'] =="Yes"]['Order_ID'].nunique()

# %%
order_date=returned_shipping_time.groupby(['Shipping Time'])['Shipping Time'].count()

# %%
order_date=returned_shipping_time.groupby(['Shipping Time'])['Shipping Time'].count()

# %% [markdown]
# số đơn bị hoàn lại theo ngày

# %%
order=df_ship1.groupby(['Shipping Time'])['Shipping Time'].count()
order=pd.DataFrame(order)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-ce128597b4c0> in <module>
# ----> 1 order=df_ship1.groupby(['Shipping Time'])['Shipping Time'].count()
#       2 order=pd.DataFrame(order)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7719         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7720         # "Union[bool, NoDefault]"; expected "bool"
# -> 7721         return DataFrameGroupBy(
#    7722             obj=self,
#    7723             keys=by,
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
# ...

# %%
order_date=pd.DataFrame(order_date)

# %%
order_date
# Out:
#                Shipping Time  Time
# Shipping Time
# 0                         64     0
# 1                         34     1
# 2                        100     2
# 3                         99     3
# 4                        201     4
# 5                        138     5
# 6                        106     6
# 7                         58     7

# %%
order_date['Time'] = order_date.index.get_level_values(0)

# %%
# Các cột ĐỨNG
plt.bar(order_date['Time'], order_date['Shipping Time'])
plt.show()
# # Sử dụng seaborn.barplot() --> ngầm định mỗi cột 1 màu
# sbn.barplot(x, y1)
# plt.show()

# %%
returned_shipping_time
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 18        19  CA-2014-143336 2014-08-27 2014-09-01    Second Class
# 19        20  CA-2014-143336 2014-08-27 2014-09-01    Second Class
# 20        21  CA-2014-143336 2014-08-27 2014-09-01    Second Class
# 55        56  CA-2016-111682 2016-06-17 2016-06-18     First Class
# 56        57  CA-2016-111682 2016-06-17 2016-06-18     First Class
# ...      ...             ...        ...        ...             ...
# 9957    9958  US-2014-143287 2014-11-11 2014-11-17  Standard Class
# 9958    9959  US-2014-143287 2014-11-11 2014-11-17  Standard Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
#
#      Customer_ID       Customer_Name      Segment        Country  \
# 18      ZD-21925  Zuschuss Donatelli     Consumer  United States
# ...

# %% [markdown]
# Sales is highest in Same Day.
# Profit is highest in First class.
# Discount is highest in first Class

# %%
# create table
data_shipping_time = df.copy()
data_shipping_time['Shipping Time'] = pd.to_datetime(data_shipping_time['Ship_Date']) - pd.to_datetime(data_shipping_time['Order_Date'])

data_shipping_time['Shipping Time'] = data_shipping_time['Shipping Time'].dt.days

data_shipping_time = data_shipping_time.groupby('Shipping Time', as_index = False).sum()

sales_data_shipping_time = data_shipping_time.sort_values(by = 'Sales')

# plot
fig = px.bar(x = sales_data_shipping_time['Sales'],
             y = sales_data_shipping_time['Shipping Time'],
             orientation = 'h',
             template = 'simple_white',
             color_discrete_sequence = colors)

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="Total Sales",
    yaxis_title="Number of Days",
    showlegend = True,
    font = dict(
            size = 14
            ),    
    title={
        'text': "Total Sales by Average Delivery Time<br>(days)",
        'y':0.95,
        'x':0.5
        }
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# create table
data_shipping_time = no_return.copy()
data_shipping_time['Shipping Time'] = pd.to_datetime(data_shipping_time['Ship_Date']) - pd.to_datetime(data_shipping_time['Order_Date'])

data_shipping_time['Shipping Time'] = data_shipping_time['Shipping Time'].dt.days

data_shipping_time = data_shipping_time.groupby('Shipping Time', as_index = False).sum()

profit_data_shipping_time = data_shipping_time.sort_values(by = 'Profit')
# plot
fig = px.bar(x = profit_data_shipping_time['Profit'],
             y = profit_data_shipping_time['Shipping Time'],
             orientation = 'h',
             template = 'simple_white',
             color_discrete_sequence = [colors[1]])

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="Total Profit",
    yaxis_title="Number of Days",
    showlegend = True,
    font = dict(
            size = 14
            ),    
    title={
        'text': "Total Profit by Average Delivery Time<br>(days)",
        'y':0.95,
         'x':0.5
        }
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# creating a custom palette
colors = ['#1192AA','#00B8C0', '#73D4D3', '#FF69B4']

sns.palplot(colors)
plt.gcf().set_size_inches(8,2.5)

for idx,values in enumerate(colors):
    plt.text(idx-0.375,0, colors[idx],{'font': "Courier New", 'size':16, 'weight':'bold','color':'black'}, alpha =0.7)
plt.gcf().set_facecolor('white')

plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Courier New' not found.
# ...

# %%
# create table
data_shipping_time = df.copy()
data_shipping_time['Shipping Time'] = pd.to_datetime(data_shipping_time['Ship_Date']) - pd.to_datetime(data_shipping_time['Order_Date'])

data_shipping_time['Shipping Time'] = data_shipping_time['Shipping Time'].dt.days

margin_data_shipping_time = data_shipping_time.groupby('Shipping Time', as_index = False).sum()

margin_data_shipping_time['Profit Margin'] = data_shipping_time['Profit'] / data_shipping_time['Sales'] * 100
# plot
fig = px.bar(x = margin_data_shipping_time['Profit Margin'],
             y = margin_data_shipping_time['Shipping Time'],
              cmap = sns.color_palette("Blues_r", n_colors=)

            )

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="Profit Margin (%)",
    yaxis_title="Number of Days",
    showlegend = False,
    font = dict(
            size = 14
            ),    
    title={
        'text': "Profit Margin by Average Delivery Time",
        'y':0.95,
        'x':0.5
        }
    )
fig.show()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-185-3f2c27dc1a71>", line 11, in <module>
#     fig = px.bar(x = margin_data_shipping_time['Profit Margin'],
# TypeError: bar() got an unexpected keyword argument 'cmap'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 2040, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %% [markdown]
# Inference:
# Sales and Profit series act normally. Some small sharp rises in sales are visible, for example on March 18, 2014 and October 2, 2016.
# Sales fluctuate more than Profit.
# There are several big bubbles, biggest red one (with a negative profit value) in March 2014. Big blue ones (with a positive profit value) began to appear more often after October 2016.
# On average, First Class orders take 2 days to deliver, Same Day 0 days (logicaly in the shipping in a same day), Second Class shipping take 3 days, and Standart Class 5 days.
# Total Sales and Total Profit distributed normally according to the number of days taken for delivery.
# Only orders that take 4 days to deliver make negative (and quite low) profit margin.

# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
import matplotlib

# %%
furniture = df.loc[df['Category'] == 'Furniture']
technology =df.loc[df['Category'] == 'Technology']
officeSupplies =df.loc[df['Category'] == 'Office Supplies']

# %%
furniture.head()
# Out:
#   Order_Date     Sales
# 0 2014-01-06  2573.820
# 1 2014-01-07    76.728
# 2 2014-01-10    51.940
# 3 2014-01-11     9.940
# 4 2014-01-13   879.939

# %%
furniture = furniture.groupby('Order_Date')['Sales'].sum().reset_index()

# %%
furniture.columns
# Out:
# Index(['Order_Date', 'Sales'], dtype='object')

# %%
y_tech = furniture['Sales'].resample('MS').mean()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-183-9297a1651f69>", line 1, in <module>
#     y_tech = furniture['Sales'].resample('MS').mean()
#   File "/usr/local/lib/python3.9/dist-packages/pandas/core/series.py", line 5428, in resample
#     return super().resample(
#   File "/usr/local/lib/python3.9/dist-packages/pandas/core/generic.py", line 8313, in resample
#     return get_resampler(
#   File "/usr/local/lib/python3.9/dist-packages/pandas/core/resample.py", line 1423, in get_resampler
#     return tg._get_resampler(obj, kind=kind)
#   File "/usr/local/lib/python3.9/dist-packages/pandas/core/resample.py", line 1599, in _get_resampler
#     raise TypeError(
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib, pandas as pd
# !pip install xlrd

matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
plt.figure(figsize=(17, 8))

plt.plot(furniture['Order_Date'], furniture['Sales'], 'b-', label = 'furniture')
plt.legend()

# %%
furniture = furniture.groupby('Order_Date')['Sales'].sum().reset_index()
furnitureTop5 =furniture.sort_values('Sales',ascending=False).head(5) 
furnitureTop5
y_tech = tech['Sales'].resample('MS').mean()
# Out:
#     Order_Date      Sales
# 326 2015-09-17  10006.174
# 626 2016-12-25   6636.863
# 377 2015-12-01   6600.680
# 802 2017-09-20   5496.174
# 171 2014-11-17   5270.080

# %%
plt.figure(figsize=(20, 8))
# creating a line chart
plt.plot(furniture['Order_Date'], furniture['Sales'])

# setting the x-axis label and rotation
plt.xlabel('Order_Date')
plt.xticks(rotation=90)

# setting the y-axis label
plt.ylabel('Sales')

# setting the chart title
plt.title('Furniture Sales Over Time')

# displaying the chart
plt.show()

# %% [markdown]
# This code creates a line chart that shows the trend of furniture sales over time. The x-axis shows the 'Order Date' values, while the y-axis shows the sum of 'Sales' for each date. The chart title is set to 'Furniture Sales Over Time'.

# %%
technology =technology.groupby('Order_Date')['Sales'].sum().reset_index()
technologyTop5 =technology.sort_values('Sales',ascending=False).head(5) 
technologyTop5
# Out:
#     Order_Date      Sales
# 21  2014-03-18  24739.748
# 519 2016-10-02  17499.950
# 626 2017-03-23  13999.960
# 769 2017-10-22  13685.258
# 789 2017-11-17  11457.180

# %%
# creating a line chart
plt.plot(technology['Order_Date'], technology['Sales'])

# setting the x-axis label and rotation
plt.xlabel('Order_Date')
plt.xticks(rotation=90)

# setting the y-axis label
plt.ylabel('Sales')

# setting the chart title
plt.title('Technology Sales Over Time')

# displaying the chart
plt.show()

# %%
officeSupplies = officeSupplies.groupby('Order_Date')['Sales'].sum().reset_index()
officeSuppliesTop5 =officeSupplies.sort_values('Sales',ascending=False).head(5) 
officeSuppliesTop5
# Out:
#      Order_Date      Sales
# 184  2014-09-23  10142.354
# 824  2016-12-17  10016.014
# 140  2014-07-25   8263.370
# 312  2015-03-16   6929.220
# 1074 2017-10-13   6648.882

# %%
plt.figure(figsize=(20, 8))
# creating a line chart
plt.plot(officeSupplies['Order_Date'],officeSupplies['Sales'])

# setting the x-axis label and rotation
plt.xlabel('Order_Date')
# plt.xticks(rotation=90)

# setting the y-axis label
plt.ylabel('Sales')

# setting the chart title
plt.title('Office Supplies Sales Over Time')

# displaying the chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Order_Date'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# creating a line chart
plt.plot(officeSupplies['Order_Date'],officeSupplies['Sales'])

# setting the x-axis label and rotation
plt.xlabel('Order_Date')
plt.xticks(rotation=90)

# setting the y-axis label
plt.ylabel('Sales')

# setting the chart title
plt.title('Office Supplies Sales Over Time')

# displaying the chart
plt.show()

# %%
# group by Order Date and Category and sum the Sales column
sales_by_date_category = df.groupby(['Order_Date', 'Category'])['Sales'].resample('MS').mean().reset_index()

# pivot the data to create a DataFrame with columns for each Category
pivot_sales = sales_by_date_category.pivot(index='Order_Date', columns='Category', values='Sales')
print(pivot_sales)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-184-3c7359d1f7a0>", line 2, in <module>
#     sales_by_date_category = df.groupby(['Order_Date', 'Category'])['Sales'].resample('MS').mean().reset_index()
#   File "/usr/local/lib/python3.9/dist-packages/pandas/core/groupby/groupby.py", line 2426, in resample
#     return get_resampler_for_grouping(self, rule, *args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/pandas/core/resample.py", line 1437, in get_resampler_for_grouping
#     resampler = tg._get_resampler(groupby.obj, kind=kind)
#   File "/usr/local/lib/python3.9/dist-packages/pandas/core/resample.py", line 1599, in _get_resampler
#     raise TypeError(
# ...

# %%
# group by Order Date and Category and sum the Sales column
sales_by_date_category = df.groupby(['Order_Date', 'Category'])['Sales'].sum().reset_index()

# pivot the data to create a DataFrame with columns for each Category
pivot_sales = sales_by_date_category.pivot(index='Order_Date', columns='Category', values='Sales')

# use a colorblind-friendly palette
palette = sns.color_palette("colorblind", len(pivot_sales.columns))

# create a line chart for each Category
for i, category in enumerate(pivot_sales.columns):
    plt.plot(pivot_sales.index, pivot_sales[category], color=palette[i], label=category)

# set the x-axis label and rotation
plt.xlabel('Order_Date')
plt.xticks(rotation=90)

# set the y-axis label
plt.ylabel('Sales')

# set the chart title
plt.title('Sales Over Time by Category')

# add a legend to the chart
plt.legend()

# display the chart
plt.show()

# %%
sales_by_date_category.head()
# Out:
#   Order_Date         Category     Sales
# 0 2014-01-03  Office Supplies    16.448
# 1 2014-01-04  Office Supplies   288.060
# 2 2014-01-05  Office Supplies    19.536
# 3 2014-01-06        Furniture  2573.820
# 4 2014-01-06  Office Supplies   685.340

# %%
# group by Order Date and Category and sum the Sales column
sales_by_date_category = df.groupby(['Order_Date', 'Category'])['Sales'].sum().reset_index()

# pivot the data to create a DataFrame with columns for each Category
pivot_sales = sales_by_date_category.pivot(index='Order_Date', columns='Category', values='Sales')

# use a colorblind-friendly palette
palette = sns.color_palette("colorblind", len(pivot_sales.columns))

# create a line chart for each Category
for i, category in enumerate(pivot_sales.columns):
    plt.plot(pivot_sales.index, pivot_sales[category], color=palette[i], label=category)

# set the x-axis label and rotation
plt.xlabel('Order_Date')
plt.xticks(rotation=90)

# set the y-axis label
plt.ylabel('Sales')

# set the chart title
plt.title('Sales Over Time by Category')

# add a legend to the chart
plt.legend()

# display the chart
plt.show()

# %% [markdown]
# technology category has the highest sales across all dates in the dataset. This is indicated by the fact that the sum of sales for the technology category is consistently higher than the sum of sales for the other categories in the sales_by_date_category DataFrame. This suggests that businesses may benefit from focusing more on technology products in order to maximize their sales and revenue.
# Moreover, this insight can also help businesses to make informed decisions about inventory management and resource allocation. For example, if the technology category consistently generates the most sales, businesses may need to allocate more resources to this category in order to keep up with demand. Knowing that technology sales is consistently the highest category of sales over time can inform businesses to focus their product development and innovation efforts on this category to drive revenue growth and maintain competitiveness in the market.

# %%
furniture = furniture.set_index('Order_Date')
furniture.index
# Out:
# DatetimeIndex(['2014-01-06', '2014-01-07', '2014-01-10', '2014-01-11',
#                '2014-01-13', '2014-01-14', '2014-01-16', '2014-01-19',
#                '2014-01-20', '2014-01-21',
#                ...
#                '2017-12-18', '2017-12-19', '2017-12-21', '2017-12-22',
#                '2017-12-23', '2017-12-24', '2017-12-25', '2017-12-28',
#                '2017-12-29', '2017-12-30'],
#               dtype='datetime64[ns]', name='Order_Date', length=889, freq=None)

# %%
furniture
# Out:
#                 Sales
# Order_Date
# 2014-01-06  2573.8200
# 2014-01-07    76.7280
# 2014-01-10    51.9400
# 2014-01-11     9.9400
# 2014-01-13   879.9390
# ...               ...
# 2017-12-24  1393.4940
# 2017-12-25   832.4540
# 2017-12-28   551.2568
# 2017-12-29  2330.7180
# 2017-12-30   323.1360
#
# [889 rows x 1 columns]

# %%
technology= technology.set_index('Order_Date')
technology.index
# Out:
# DatetimeIndex(['2014-01-06', '2014-01-09', '2014-01-13', '2014-01-15',
#                '2014-01-16', '2014-01-20', '2014-01-26', '2014-02-01',
#                '2014-02-02', '2014-02-06',
#                ...
#                '2017-12-18', '2017-12-21', '2017-12-22', '2017-12-23',
#                '2017-12-24', '2017-12-25', '2017-12-27', '2017-12-28',
#                '2017-12-29', '2017-12-30'],
#               dtype='datetime64[ns]', name='Order_Date', length=824, freq=None)

# %%
technology
# Out:
#                Sales
# Order_Date
# 2014-01-06  1147.940
# 2014-01-09    31.200
# 2014-01-13   646.740
# 2014-01-15   149.950
# 2014-01-16   124.200
# ...              ...
# 2017-12-25   401.208
# 2017-12-27   164.388
# 2017-12-28    14.850
# 2017-12-29   302.376
# 2017-12-30    90.930
#
# [824 rows x 1 columns]

# %%
officeSupplies = officeSupplies.set_index('Order_Date')
officeSupplies.index
# Out:
# DatetimeIndex(['2014-01-03', '2014-01-04', '2014-01-05', '2014-01-06',
#                '2014-01-07', '2014-01-09', '2014-01-10', '2014-01-13',
#                '2014-01-16', '2014-01-18',
#                ...
#                '2017-12-21', '2017-12-22', '2017-12-23', '2017-12-24',
#                '2017-12-25', '2017-12-26', '2017-12-27', '2017-12-28',
#                '2017-12-29', '2017-12-30'],
#               dtype='datetime64[ns]', name='Order_Date', length=1148, freq=None)

# %%
officeSupplies
# Out:
#                Sales
# Order_Date
# 2014-01-03    16.448
# 2014-01-04   288.060
# 2014-01-05    19.536
# 2014-01-06   685.340
# 2014-01-07    10.430
# ...              ...
# 2017-12-26   814.594
# 2017-12-27    13.248
# 2017-12-28  1091.244
# 2017-12-29   282.440
# 2017-12-30   299.724
#
# [1148 rows x 1 columns]

# %% [markdown]
# 6. Visualizing Sales Time Series Data for Different Categories

# %%
yf = furniture['Sales'].resample('MS').mean() #resamples the data at a no_return frequency, with 'MS' indicating the start of each month. This is accomplished by grouping the data by month and generating a new time series index at the start of each month.

# %%
yf.plot(figsize=(15, 6))

plt.ylabel('Avg Daily Sales')
# setting the chart title
plt.title('Furniture Sales Time Series Data')
plt.show()

# %%
yt = technology['Sales'].resample('MS').mean()

# %%
yO = officeSupplies['Sales'].resample('MS').mean()

# %%
yt.plot(figsize=(15, 6))
plt.ylabel('Avg Daily Sales')
# setting the chart title
plt.title('Technology Sales Time Series Data')
plt.show()

# %%
yO.plot(figsize=(15, 6))
plt.ylabel('Avg Daily Sales')
# setting the chart title
plt.title('Office Supplies Sales Time Series Data')
plt.show()

# %% [markdown]
# Some distinguishable patterns appear when we plot the data. The time-series has seasonality pattern, such as sales are always low at the beginning of the year and high at the end of the year. There is always an upward trend within any single year with a couple of low months in the mid of the year.
#
# We can also visualize our data using a method called time-series decomposition that allows us to decompose our time series into three distinct components: trend, seasonality, and noise.

# %% [markdown]
# Furniture Sales

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(yf, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# Technology Sales

# %%
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(yt, model='additive')
fig = decomposition.plot()
plt.show()

# %%
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(yO, model='additive')
fig = decomposition.plot()
plt.show()
